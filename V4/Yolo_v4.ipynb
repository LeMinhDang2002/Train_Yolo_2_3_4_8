# %%
class_names = ['motobike']

num_classes = len(class_names)

from os import path

from collections.abc import Iterable
# from keras.src.utils import Sequence

from utils import tools

# %%
class Yolo_data(object):

    def __init__(self,
                 input_shape=(416, 416, 3),
                 class_names=[]):
        self.input_shape = input_shape
        self.grid_shape = input_shape[0]//32, input_shape[1]//32
        self.class_names = class_names
        self.class_num = len(class_names)
        self.fpn_layers = 3
        self.file_names = None
        
    def read_file_to_dataset(
        self, img_path=None, label_path=None,
        label_format="labelimg",
        rescale=1/255,
        preprocessing=None,
        augmenter=None,
        aug_times=1,
        shuffle=True, seed=None,
        encoding="big5",
        thread_num=10):
        
        grid_amp = 2**(self.fpn_layers - 1)
        grid_shape = (self.grid_shape[0]*grid_amp,
                      self.grid_shape[1]*grid_amp)
        img_data, label_data, path_list = tools.read_file(
            img_path=img_path, 
            label_path=label_path,
            label_format=label_format,
            size=self.input_shape[:2], 
            grid_shape=grid_shape,
            class_names=self.class_names,
            rescale=rescale,
            preprocessing=preprocessing,
            augmenter=augmenter,
            aug_times=aug_times,
            shuffle=shuffle, seed=seed,
            encoding=encoding,
            thread_num=thread_num)
        self.file_names = path_list

        label_list = [label_data]
        for _ in range(self.fpn_layers - 1):
            label_data = tools.down2xlabel(label_data)
            label_list.insert(0, label_data)

        return img_data, label_list

    def vis_img(self, img, *label_datas,
                conf_threshold=0.5,
                show_conf=True,
                nms_mode=0,
                nms_threshold=0.5,
                nms_sigma=0.5,
                **kwargs):

        return tools.vis_img(
                             img, 
                             *label_datas, 
                             class_names=self.class_names,
                             conf_threshold=conf_threshold,
                             show_conf=show_conf,
                             nms_mode=nms_mode,  
                             nms_threshold=nms_threshold,
                             nms_sigma=nms_sigma,
                             version=3,
                             **kwargs)

# %%
# yolo_data = Yolo_data(class_names=class_names)
# img_path   = "../Mydata/TrainImage/"
# label_path = "../Mydata/XMLTrainImage/"

# train_img, train_label = yolo_data.read_file_to_dataset(
#     img_path, label_path,
#     label_format="labelimg",
#     thread_num=1,
#     shuffle=False)

# %%
# print(len(train_label))

# %%
# img_path   = "../Mydata/ValImage/"
# label_path = "../Mydata/XMLValImage/"

# val_img, val_label = yolo_data.read_file_to_dataset(
#     img_path, label_path,
#     label_format="labelimg",
#     thread_num=1,
#     shuffle=False)

# %%
# for i in range(5):
#     yolo_data.vis_img(
#         train_img[i], train_label[2][i],
#         show_conf=False)

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, concatenate, ZeroPadding2D, LeakyReLU, BatchNormalization
from keras.initializers import RandomNormal
from keras.regularizers import l2
import tensorflow as tf
import numpy as np

n_epoch = 10
epsilon = 1e-07

# %%
## Leaky Convolutional
class DarknetConv2D(Conv2D):
    '''Convolution2D with Darknet parameters.
    '''
    __doc__ += Conv2D.__doc__
    def __init__(self, *args, **kwargs):
        kwargs["kernel_initializer"] = RandomNormal(mean=0.0, stddev=0.02)
        if kwargs.get("strides") == (2, 2):
            kwargs["padding"] = "valid"
        else:
            kwargs["padding"] = "same"
        super().__init__(*args, **kwargs)

# %%
'''
05. Mish Activation
'''
def mish(x):
    return x * tf.math.tanh(tf.math.softplus(x))

# %%
## CSP Residual Block
def DarknetConv2D_BN_Leaky(input_layer, filters_shape, downsample=False, activate=True, bn=True, activate_type='leaky'):
    if downsample:
        input_layer = ZeroPadding2D(((1, 0), (1, 0)))(input_layer)
        padding = 'valid'
        strides = 2
    else:
        strides = 1
        padding = 'same'

    conv = Conv2D(filters=filters_shape[-1], kernel_size = filters_shape[0], strides=strides,
                  padding=padding, use_bias=not bn, kernel_regularizer=l2(0.0005),
                  kernel_initializer=tf.random_normal_initializer(stddev=0.01),
                  bias_initializer=tf.constant_initializer(0.))(input_layer)
    if bn:
        conv = BatchNormalization()(conv)
    if activate == True:
        if activate_type == "leaky":
            conv = LeakyReLU(alpha=0.1)(conv)
        elif activate_type == "mish":
            conv = mish(conv)

    return conv

def DarknetResidual(input_layer, input_channel, filter_num1, filter_num2, activate_type='leaky'):
    short_cut = input_layer
    conv = DarknetConv2D_BN_Leaky(input_layer, filters_shape=(1, 1, input_channel, filter_num1), activate_type=activate_type)
    conv = DarknetConv2D_BN_Leaky(conv       , filters_shape=(3, 3, filter_num1,   filter_num2), activate_type=activate_type)

    residual_output = short_cut + conv
    return residual_output

def upsample(input_layer):
    return tf.image.resize(input_layer, (input_layer.shape[1] * 2, input_layer.shape[2] * 2), method='nearest')

# %%
### CSP Backbone darknet

def CSP_Backbone_darknet(input_tensor):
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3,  3,  32), activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 32,  64), downsample=True, activate_type="mish")

    route = input_tensor
    route = DarknetConv2D_BN_Leaky(route, (1, 1, 64, 64), activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 64, 64), activate_type="mish")
    for i in range(1):
        input_tensor = DarknetResidual(input_tensor,  64,  32, 64, activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 64, 64), activate_type="mish")

    input_tensor = tf.concat([input_tensor, route], axis=-1)
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 128, 64), activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 64, 128), downsample=True, activate_type="mish")
    route = input_tensor
    route = DarknetConv2D_BN_Leaky(route, (1, 1, 128, 64), activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 128, 64), activate_type="mish")
    for i in range(2):
        input_tensor = DarknetResidual(input_tensor, 64,  64, 64, activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 64, 64), activate_type="mish")
    input_tensor = tf.concat([input_tensor, route], axis=-1)

    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 128, 128), activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 128, 256), downsample=True, activate_type="mish")
    route = input_tensor
    route = DarknetConv2D_BN_Leaky(route, (1, 1, 256, 128), activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 256, 128), activate_type="mish")
    for i in range(8):
        input_tensor = DarknetResidual(input_tensor, 128, 128, 128, activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 128, 128), activate_type="mish")
    input_tensor = tf.concat([input_tensor, route], axis=-1)

    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 256, 256), activate_type="mish")
    route_1 = input_tensor
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 256, 512), downsample=True, activate_type="mish")
    route = input_tensor
    route = DarknetConv2D_BN_Leaky(route, (1, 1, 512, 256), activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 512, 256), activate_type="mish")
    for i in range(8):
        input_tensor = DarknetResidual(input_tensor, 256, 256, 256, activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 256, 256), activate_type="mish")
    input_tensor = tf.concat([input_tensor, route], axis=-1)

    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 512, 512), activate_type="mish")
    route_2 = input_tensor
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 512, 1024), downsample=True, activate_type="mish")
    route = input_tensor
    route = DarknetConv2D_BN_Leaky(route, (1, 1, 1024, 512), activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 1024, 512), activate_type="mish")
    for i in range(4):
        input_tensor = DarknetResidual(input_tensor, 512, 512, 512, activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 512, 512), activate_type="mish")
    input_tensor = tf.concat([input_tensor, route], axis=-1)

    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 1024, 1024), activate_type="mish")
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 1024, 512))
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 512, 1024))
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 1024, 512))

    input_tensor = tf.concat([tf.nn.max_pool(input_tensor, ksize=13, padding='SAME', strides=1), tf.nn.max_pool(input_tensor, ksize=9, padding='SAME', strides=1)
                            , tf.nn.max_pool(input_tensor, ksize=5, padding='SAME', strides=1), input_tensor], axis=-1)
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 2048, 512))
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 512, 1024))
    input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 1024, 512))

    return route_1, route_2, input_tensor

# %%
# ### CSP Backbone darknet

# def CSP_Backbone_darknet(input_tensor):
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3,  3,  32), activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 32,  64), downsample=True, activate_type="leaky")

#     route = input_tensor
#     route = DarknetConv2D_BN_Leaky(route, (1, 1, 64, 64), activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 64, 64), activate_type="leaky")
#     for i in range(1):
#         input_tensor = DarknetResidual(input_tensor,  64,  32, 64, activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 64, 64), activate_type="leaky")

#     input_tensor = tf.concat([input_tensor, route], axis=-1)
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 128, 64), activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 64, 128), downsample=True, activate_type="leaky")
#     route = input_tensor
#     route = DarknetConv2D_BN_Leaky(route, (1, 1, 128, 64), activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 128, 64), activate_type="leaky")
#     for i in range(2):
#         input_tensor = DarknetResidual(input_tensor, 64,  64, 64, activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 64, 64), activate_type="leaky")
#     input_tensor = tf.concat([input_tensor, route], axis=-1)

#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 128, 128), activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 128, 256), downsample=True, activate_type="leaky")
#     route = input_tensor
#     route = DarknetConv2D_BN_Leaky(route, (1, 1, 256, 128), activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 256, 128), activate_type="leaky")
#     for i in range(8):
#         input_tensor = DarknetResidual(input_tensor, 128, 128, 128, activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 128, 128), activate_type="leaky")
#     input_tensor = tf.concat([input_tensor, route], axis=-1)

#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 256, 256), activate_type="leaky")
#     route_1 = input_tensor
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 256, 512), downsample=True, activate_type="leaky")
#     route = input_tensor
#     route = DarknetConv2D_BN_Leaky(route, (1, 1, 512, 256), activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 512, 256), activate_type="leaky")
#     for i in range(8):
#         input_tensor = DarknetResidual(input_tensor, 256, 256, 256, activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 256, 256), activate_type="leaky")
#     input_tensor = tf.concat([input_tensor, route], axis=-1)

#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 512, 512), activate_type="leaky")
#     route_2 = input_tensor
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 512, 1024), downsample=True, activate_type="leaky")
#     route = input_tensor
#     route = DarknetConv2D_BN_Leaky(route, (1, 1, 1024, 512), activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 1024, 512), activate_type="leaky")
#     for i in range(4):
#         input_tensor = DarknetResidual(input_tensor, 512, 512, 512, activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 512, 512), activate_type="leaky")
#     input_tensor = tf.concat([input_tensor, route], axis=-1)

#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 1024, 1024), activate_type="leaky")
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 1024, 512))
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 512, 1024))
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 1024, 512))

#     input_tensor = tf.concat([tf.nn.max_pool(input_tensor, ksize=13, padding='SAME', strides=1), tf.nn.max_pool(input_tensor, ksize=9, padding='SAME', strides=1)
#                             , tf.nn.max_pool(input_tensor, ksize=5, padding='SAME', strides=1), input_tensor], axis=-1)
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 2048, 512))
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (3, 3, 512, 1024))
#     input_tensor = DarknetConv2D_BN_Leaky(input_tensor, (1, 1, 1024, 512))

#     return route_1, route_2, input_tensor

# %%
# ### SPP Module
# WEIGHTS_PATH_YOLOV4_BODY = "https://github.com/samson6460/tf2_YOLO/releases/download/YOLOv4/tf_keras_yolov4_608_body.h5"
# WEIGHTS_PATH_YOLOV4_MODEL = "https://github.com/samson6460/tf2_YOLO/releases/download/YOLOv4/tf_keras_yolov4_608_model.h5"
# WEIGHTS_PATH_CSPDN53_TOP = "https://github.com/samson6460/tf2_YOLO/releases/download/YOLOv4/tf_keras_darknet53_448_include_top.h5"
# WEIGHTS_PATH_CSPDN53_NOTOP = "https://github.com/samson6460/tf2_YOLO/releases/download/YOLOv4/tf_keras_darknet53_448_no_top.h5"

# %%
## YOLO Neck
def yolo_neck(input_shape=(608, 608, 3),
              pretrained_darknet=None,
              pretrained_weights=None):
    '''Create YOLOv4 body in tf.keras.'''
    input_tensor = Input(input_shape)
    # darknet = Model(input_tensor, CSP_Backbone_darknet(input_tensor))
    route_1, route_2, conv = CSP_Backbone_darknet(input_tensor)
    
    # if pretrained_darknet is not None:
    #     darknet.set_weights(pretrained_darknet.get_weights())
    
    tensor_s_up = DarknetConv2D_BN_Leaky(conv, (1, 1, 512, 256))
    tensor_s_up = upsample(tensor_s_up)
    
    tensor_m = DarknetConv2D_BN_Leaky(route_2, (1, 1, 512, 256))
    tensor_m = tf.concat([tensor_m, tensor_s_up], axis=-1)
    
    tensor_m = DarknetConv2D_BN_Leaky(tensor_m, (1, 1, 512, 256))
    tensor_m = DarknetConv2D_BN_Leaky(tensor_m, (3, 3, 256, 512))
    tensor_m = DarknetConv2D_BN_Leaky(tensor_m, (1, 1, 512, 256))
    tensor_m = DarknetConv2D_BN_Leaky(tensor_m, (3, 3, 256, 512))
    tensor_m = DarknetConv2D_BN_Leaky(tensor_m, (1, 1, 512, 256))
    
    tensor_m_up = DarknetConv2D_BN_Leaky(tensor_m, (1, 1, 256, 128))
    tensor_m_up = upsample(tensor_m_up)
    
    tensor_l = DarknetConv2D_BN_Leaky(route_1, (1, 1, 256, 128))
    tensor_l = tf.concat([tensor_l, tensor_m_up], axis=-1)
    
    tensor_l = DarknetConv2D_BN_Leaky(tensor_l, (1, 1, 256, 128))
    tensor_l = DarknetConv2D_BN_Leaky(tensor_l, (3, 3, 128, 256))
    tensor_l = DarknetConv2D_BN_Leaky(tensor_l, (1, 1, 256, 128))
    tensor_l = DarknetConv2D_BN_Leaky(tensor_l, (3, 3, 128, 256))
    tensor_l = DarknetConv2D_BN_Leaky(tensor_l, (1, 1, 256, 128))
    
    output_l = DarknetConv2D_BN_Leaky(tensor_l, (3, 3, 128, 256))

    tensor_l_dn = ZeroPadding2D(((1, 0),(1, 0)), name="pan_bu1_dn_pad")(tensor_l)
    tensor_l_dn = DarknetConv2D_BN_Leaky(tensor_l_dn, (3, 3, 128, 256), downsample=True)
    
    tensor_m = tf.concat([tensor_l_dn, tensor_m], axis=-1)
    
    tensor_m = DarknetConv2D_BN_Leaky(tensor_m, (1, 1, 512, 256))
    tensor_m = DarknetConv2D_BN_Leaky(tensor_m, (3, 3, 256, 512))
    tensor_m = DarknetConv2D_BN_Leaky(tensor_m, (1, 1, 512, 256))
    tensor_m = DarknetConv2D_BN_Leaky(tensor_m, (3, 3, 256, 512))
    tensor_m = DarknetConv2D_BN_Leaky(tensor_m, (1, 1, 512, 256))
    
    output_m = DarknetConv2D_BN_Leaky(tensor_m, (3, 3, 256, 512))

    tensor_m_dn = ZeroPadding2D(((1, 0),(1, 0)), name="pan_bu2_dn_pad")(tensor_m)
    tensor_m_dn = DarknetConv2D_BN_Leaky(tensor_m_dn, (3, 3, 256, 512), downsample=True)
    
    tensor_s = tf.concat([tensor_m_dn, conv], axis=-1)
    
    tensor_s = DarknetConv2D_BN_Leaky(tensor_s, (1, 1, 1024, 512))
    tensor_s = DarknetConv2D_BN_Leaky(tensor_s, (3, 3, 512, 1024))
    tensor_s = DarknetConv2D_BN_Leaky(tensor_s, (1, 1, 1024, 512))
    tensor_s = DarknetConv2D_BN_Leaky(tensor_s, (3, 3, 512, 1024))
    tensor_s = DarknetConv2D_BN_Leaky(tensor_s, (1, 1, 1024, 512))
    
    output_s = DarknetConv2D_BN_Leaky(tensor_s, (3, 3, 512, 1024))

    model = Model(input_tensor, [output_s, output_m, output_l])
    
    '''
    if pretrained_weights is not None:
        if pretrained_weights == "ms_coco":
            pretrained_weights = get_file(
                "tf_keras_yolov4_body.h5",
                WEIGHTS_PATH_YOLOV4_BODY,
                cache_subdir="models")
        model.load_weights(pretrained_weights)
    '''
    return model

# %%
## Head
def yolo_head(model_body, class_num=10, 
              anchors=[[0.89663461, 0.78365384],
                       [0.37500000, 0.47596153],
                       [0.27884615, 0.21634615],
                       [0.14182692, 0.28605769],
                       [0.14903846, 0.10817307],
                       [0.07211538, 0.14663461],
                       [0.07932692, 0.05528846],
                       [0.03846153, 0.07211538],
                       [0.02403846, 0.03125000]]):
    anchors = np.array(anchors)
    inputs = model_body.input
    output = model_body.output
    tensor_num = len(output)

    if len(anchors)%tensor_num > 0:
        raise ValueError(("The total number of anchor boxs"
                          " should be a multiple of the number(%s)"
                          " of output tensors") % tensor_num)    
    abox_num = len(anchors)//tensor_num

    outputs_list = []
    for tensor_i, output_tensor in enumerate(output):
        output_list = []
        start_i = tensor_i*abox_num
        for box in anchors[start_i:start_i + abox_num]:
            xy_output = DarknetConv2D(2, 1,
                            activation='sigmoid')(output_tensor)
            wh_output = DarknetConv2D(2, 1,
                            activation='exponential')(output_tensor)
            wh_output = wh_output * box
            c_output = DarknetConv2D(1, 1,
                            activation='sigmoid')(output_tensor)
            p_output = DarknetConv2D(class_num, 1,
                            activation='sigmoid')(output_tensor)
                            # activation='softmax')(output_tensor)
            output_list += [xy_output,
                            wh_output,
                            c_output,
                            p_output]

        outputs = concatenate(output_list, axis=-1)
        outputs_list.append(outputs)
    
    model = Model(inputs, outputs_list)    

    return model

# %%
## Complete Intersection over Union
import math
def cal_iou(xywh_true, xywh_pred, grid_shape, return_ciou=False):
    '''Calculate IOU of two tensors.
    return shape: (N, S, S, B)[, (N, S, S, B)]
    '''
    grid_shape = np.array(grid_shape[::-1])
    xy_true = xywh_true[..., 0:2]/grid_shape # N*S*S*1*2
    wh_true = xywh_true[..., 2:4]

    xy_pred = xywh_pred[..., 0:2]/grid_shape # N*S*S*B*2
    wh_pred = xywh_pred[..., 2:4]
    
    half_xy_true = wh_true / 2.
    mins_true    = xy_true - half_xy_true
    maxes_true   = xy_true + half_xy_true

    half_xy_pred = wh_pred / 2.
    mins_pred    = xy_pred - half_xy_pred
    maxes_pred   = xy_pred + half_xy_pred       
    
    intersect_mins  = tf.maximum(mins_pred,  mins_true)
    intersect_maxes = tf.minimum(maxes_pred, maxes_true)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = wh_true[..., 0] * wh_true[..., 1]
    pred_areas = wh_pred[..., 0] * wh_pred[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = intersect_areas/(union_areas + epsilon)

    if return_ciou:
        enclose_mins = tf.minimum(mins_pred,  mins_true)
        enclose_maxes = tf.maximum(maxes_pred, maxes_true)

        enclose_wh = enclose_maxes - enclose_mins
        enclose_c2 = (tf.pow(enclose_wh[..., 0], 2)
                      + tf.pow(enclose_wh[..., 1], 2))

        p_rho2 = (tf.pow(xy_true[..., 0] - xy_pred[..., 0], 2)
                  + tf.pow(xy_true[..., 1] - xy_pred[..., 1], 2))

        atan_true = tf.atan(wh_true[..., 0] / (wh_true[..., 1] + epsilon))
        atan_pred = tf.atan(wh_pred[..., 0] / (wh_pred[..., 1] + epsilon))

        v_nu = 4.0 / (math.pi ** 2) * tf.pow(atan_true - atan_pred, 2)
        a_alpha = v_nu / (1 - iou_scores + v_nu)

        ciou_scores = iou_scores - p_rho2/enclose_c2 - a_alpha*v_nu

        return iou_scores, ciou_scores

    return iou_scores

# %%
## Yolo Loss Function
def wrap_yolo_loss(grid_shape,
                   bbox_num,
                   class_num,
                   anchors=None,
                   binary_weight=1,
                   loss_weight=[1, 1, 1],
                   wh_reg_weight=0.01,
                   ignore_thresh=.6,
                   truth_thresh=1,
                   label_smooth=0,
                   focal_loss_gamma=2):
    '''Wrapped YOLOv4 loss function.'''
    def yolo_loss(y_true, y_pred):
        if anchors is None:
            panchors = 1
        else:
            panchors = tf.reshape(anchors, (1, 1, 1, bbox_num, 2))

        y_true = tf.reshape(
            y_true,
            (-1, *grid_shape, 1, 5 + class_num)) # N*S*S*1*(5+C)
        y_pred = tf.reshape(
            y_pred,
            (-1, *grid_shape, bbox_num, 5 + class_num)) # N*S*S*B*(5+C)

        xywh_true = y_true[..., :4] # N*S*S*1*4
        xywh_pred = y_pred[..., :4] # N*S*S*B*4

        iou_scores, ciou_scores = cal_iou(
            xywh_true, xywh_pred, grid_shape, return_ciou=True) # N*S*S*B
        
        response_mask = tf.one_hot(tf.argmax(iou_scores, axis=-1),
                                   depth=bbox_num,
                                   dtype=xywh_true.dtype) # N*S*S*B

        has_obj_mask = y_true[..., 4]*response_mask # N*S*S*B

        if truth_thresh < 1:
            truth_mask = tf.cast(
                iou_scores > truth_thresh,
                iou_scores.dtype) # N*S*S*B
            has_obj_mask = has_obj_mask + truth_mask*(1 - has_obj_mask)
        has_obj_mask_exp = tf.expand_dims(has_obj_mask, axis=-1) # N*S*S*B*1

        no_obj_mask = tf.cast(
            iou_scores < ignore_thresh,
            iou_scores.dtype) # N*S*S*B
        no_obj_mask = (1 - has_obj_mask)*no_obj_mask # N*S*S*B

        box_loss = tf.reduce_sum(
            tf.reduce_mean(
            has_obj_mask # N*S*S*B
            *(1 - ciou_scores), # N*S*S*B
            axis=0))

        c_pred = y_pred[..., 4] # N*S*S*B
        c_pred = tf.clip_by_value(c_pred, epsilon, 1 - epsilon)

        if label_smooth > 0:
            label = 1 - label_smooth

            has_obj_c_loss = -tf.reduce_sum(
                tf.reduce_mean(
                has_obj_mask # N*S*S*B
                *(tf.math.abs(label - c_pred)**focal_loss_gamma)
                *tf.math.log(1 - tf.math.abs(label - c_pred)),
                axis=0))
            
            no_obj_c_loss = -tf.reduce_sum(
                tf.reduce_mean(
                no_obj_mask # N*S*S*B
                *(tf.math.abs(label_smooth - c_pred)**focal_loss_gamma)
                *tf.math.log(1 - tf.math.abs(label_smooth - c_pred)),
                axis=0))
        else:
            has_obj_c_loss = -tf.reduce_sum(
                tf.reduce_mean(
                has_obj_mask # N*S*S*B
                *((1 - c_pred)**focal_loss_gamma)
                *tf.math.log(c_pred),
                axis=0))

            no_obj_c_loss = -tf.reduce_sum(
                tf.reduce_mean(
                no_obj_mask # N*S*S*B
                *((c_pred)**focal_loss_gamma)
                *tf.math.log(1 - c_pred),
                axis=0))
        
        c_loss = has_obj_c_loss + binary_weight*no_obj_c_loss

        p_true = y_true[..., -class_num:] # N*S*S*1*C
        p_pred = y_pred[..., -class_num:] # N*S*S*B*C
        p_pred = tf.clip_by_value(p_pred, epsilon, 1 - epsilon)
        p_loss = -tf.reduce_sum(
            tf.reduce_mean(
                has_obj_mask_exp # N*S*S*B*1
                *(p_true*tf.math.log(p_pred)
                + (1 - p_true)*tf.math.log(1 - p_pred)), # N*S*S*B*C
                axis=0))
        
        wh_pred = y_pred[..., 2:4]/panchors # N*S*S*B*2
        wh_pred = tf.math.log(wh_pred) # N*S*S*B*2

        wh_reg = tf.reduce_sum(
            tf.reduce_mean(wh_pred**2, axis=0))

        loss = (loss_weight[0]*box_loss
                + loss_weight[1]*c_loss
                + loss_weight[2]*p_loss
                + wh_reg_weight*wh_reg)

        return loss

    return yolo_loss

# %%
### Object Accuracy
from keras.metrics import binary_accuracy

def wrap_obj_acc(grid_shape, bbox_num, class_num):
    def obj_acc(y_true, y_pred):
        y_true = tf.reshape(
            y_true,
            (-1, *grid_shape, 1, 5 + class_num)) # N*S*S*1*5+C
        y_pred = tf.reshape(
            y_pred,
            (-1, *grid_shape, bbox_num, 5 + class_num)) # N*S*S*B*5+C
        
        c_true = y_true[..., 4] # N*S*S*1
        c_pred = tf.reduce_max(y_pred[..., 4], # N*S*S*B
                               axis=-1,
                               keepdims=True) # N*S*S*1

        bi_acc = binary_accuracy(c_true, c_pred)

        return bi_acc
    return obj_acc

def wrap_mean_iou(grid_shape, bbox_num, class_num):
    def mean_iou(y_true, y_pred):
        y_true = tf.reshape(
            y_true,
            (-1, *grid_shape, 1, 5 + class_num)) # N*S*S*1*5+C
        y_pred = tf.reshape(
            y_pred,
            (-1, *grid_shape, bbox_num, 5 + class_num)) # N*S*S*B*5+C

        has_obj_mask = y_true[..., 4] # N*S*S*1
        
        xywh_true = y_true[..., :4] # N*S*S*1*4
        xywh_pred = y_pred[..., :4] # N*S*S*B*4

        iou_scores = cal_iou(xywh_true, xywh_pred, grid_shape) # N*S*S*B
        iou_scores = tf.reduce_max(iou_scores, axis=-1, keepdims=True) # N*S*S*1
        iou_scores = iou_scores*has_obj_mask # N*S*S*1

        num_p = tf.reduce_sum(has_obj_mask)

        return tf.reduce_sum(iou_scores)/(num_p + epsilon)
    return mean_iou

def wrap_class_acc(grid_shape, bbox_num, class_num):
    def class_acc(y_true, y_pred):
        y_true = tf.reshape(
            y_true,
            (-1, *grid_shape, 1, 5 + class_num)) # N*S*S*1*5+C
        y_pred = tf.reshape(
            y_pred,
            (-1, *grid_shape, bbox_num, 5 + class_num)) # N*S*S*B*5+C

        has_obj_mask = y_true[..., 4] # N*S*S*1

        pi_true = tf.argmax(y_true[..., -class_num:], # N*S*S*1*C
                            axis=-1) # N*S*S*1
        pi_pred = tf.argmax(y_pred[..., -class_num:], # N*S*S*B*C
                            axis=-1) # N*S*S*B
        
        equal_mask = tf.cast(pi_true == pi_pred,
                             dtype=y_true.dtype) # N*S*S*B
        equal_mask = equal_mask*has_obj_mask # N*S*S*B

        num_p = tf.reduce_sum(has_obj_mask)*bbox_num

        return tf.reduce_sum(equal_mask)/(num_p + epsilon)
    return class_acc

# %%
### Build Class for Model, Loss, Metrics
class Yolo(object):

    def __init__(self,
                 input_shape=(416, 416, 3),
                 class_names=[]):
        self.input_shape = input_shape
        self.grid_shape = input_shape[0]//32, input_shape[1]//32
        self.abox_num = 3
        self.class_names = class_names
        self.class_num = len(class_names)
        self.fpn_layers = 3
        self.anchors = None
        self.model = None
        self.file_names = None
        
    '''
    18. Model Create
    '''
    def create_model(self,
                     anchors=[[0.89663461, 0.78365384],
                              [0.37500000, 0.47596153],
                              [0.27884615, 0.21634615],
                              [0.14182692, 0.28605769],
                              [0.14903846, 0.10817307],
                              [0.07211538, 0.14663461],
                              [0.07932692, 0.05528846],
                              [0.03846153, 0.07211538],
                              [0.02403846, 0.03125000]],
                     backbone="full_darknet",
                     pretrained_weights=None,
                    #  pretrained_darknet="ms_coco"):
                     pretrained_darknet=None):
        
        if isinstance(pretrained_darknet, str):
            pre_body_weights = pretrained_darknet
            pretrained_darknet = None
        else:
            pre_body_weights = None
        
        model_body = yolo_neck(self.input_shape,
            pretrained_weights=pre_body_weights)

        if pretrained_darknet is not None:
            model_body.set_weights(pretrained_darknet.get_weights())
        self.model = yolo_head(model_body,
                               self.class_num,
                               anchors)
         
        if pretrained_weights is not None:
            self.model.load_weights(pretrained_weights)
        self.anchors = anchors
        self.grid_shape = self.model.output[0].shape[1:3]
        self.fpn_layers = len(self.model.output)
        self.abox_num = len(self.anchors)//self.fpn_layers

    '''
    19. Loss Create
    '''
    def loss(self,
             binary_weight=1,
             loss_weight=[1, 1, 5, 1],
             ignore_thresh=0.6):

        if (not isinstance(binary_weight, Iterable)
            or len(binary_weight) != self.fpn_layers):
            binary_weight = [binary_weight]*self.fpn_layers
        
        if isinstance(loss_weight, dict):
            loss_weight_list = []
            loss_weight_list.append(loss_weight["xy"])
            loss_weight_list.append(loss_weight["wh"])
            loss_weight_list.append(loss_weight["conf"])
            loss_weight_list.append(loss_weight["prob"])
            loss_weight = loss_weight_list
        
        loss_list = []
        for fpn_id in range(self.fpn_layers):
            grid_amp = 2**(fpn_id)
            grid_shape = (self.grid_shape[0]*grid_amp,
                          self.grid_shape[1]*grid_amp)
            anchors_id = self.abox_num*fpn_id
            loss_list.append(wrap_yolo_loss(
                grid_shape=grid_shape,
                bbox_num=self.abox_num, 
                class_num=self.class_num,
                anchors=self.anchors[
                    anchors_id:anchors_id + self.abox_num],
                binary_weight=binary_weight[fpn_id],
                loss_weight=loss_weight,
                ignore_thresh=ignore_thresh))
        return loss_list
    
    '''
    20. Metrics Create
    '''
    def metrics(self, type="obj_acc"):
        
        metrics_list = [[] for _ in range(self.fpn_layers)]
        for fpn_id in range(self.fpn_layers):
            grid_amp = 2**(fpn_id)
            grid_shape = (self.grid_shape[0]*grid_amp,
                            self.grid_shape[1]*grid_amp)
            
            if "obj" in type:
                metrics_list[fpn_id].append(
                    wrap_obj_acc(
                        grid_shape,
                        self.abox_num, 
                        self.class_num))
            if "iou" in type:
                metrics_list[fpn_id].append(
                    wrap_mean_iou(
                        grid_shape,
                        self.abox_num, 
                        self.class_num))
            if "class" in type:
                metrics_list[fpn_id].append(
                    wrap_class_acc(
                        grid_shape,
                        self.abox_num, 
                        self.class_num))
        
        return metrics_list

# %%
yolo = Yolo(class_names=class_names)

# %%
# from utils.kmeans import kmeans, iou_dist, euclidean_dist
# import numpy as np

# all_boxes = train_label[2][train_label[2][..., 4] == 1][..., 2:4]
# anchors = kmeans(
#     all_boxes,
#     n_cluster=9,
#     dist_func=iou_dist,
#     stop_dist=0.000001)

# anchors = np.sort(anchors, axis=0)[::-1]
# display(anchors)

# %%
# anchors=[[0.26923078, 0.26923078],
#         [0.20192307, 0.20192307],
#         [0.19016773, 0.13461539],
#         [0.13461539, 0.10096154],
#         [0.10120743, 0.0673077 ],
#         [0.10096154, 0.06188303],
#         [0.0673077 , 0.05288462],
#         [0.05288462, 0.05113026],
#         [0.03365385, 0.03365385]]
anchors=[[0.17842099, 0.24545719],
       [0.16058964, 0.21712816],
       [0.13592426, 0.18043523]]


yolo.create_model(anchors=anchors)
yolo.model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 416, 416, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 416, 416, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 416, 416, 32)         128       ['conv2d[0][0]']
#  Normalization)
#
#  tf.math.softplus (TFOpLamb  (None, 416, 416, 32)         0         ['batch_normalization[0][0]']
#  da)
#
#  tf.math.tanh (TFOpLambda)   (None, 416, 416, 32)         0         ['tf.math.softplus[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 416, 416, 32)         0         ['batch_normalization[0][0]',
#  da)                                                                 'tf.math.tanh[0][0]']
#
#  zero_padding2d (ZeroPaddin  (None, 417, 417, 32)         0         ['tf.math.multiply[0][0]']
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 208, 208, 64)         18432     ['zero_padding2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 208, 208, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  tf.math.softplus_1 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_1[0][0]'
#  mbda)                                                              ]
#
#  tf.math.tanh_1 (TFOpLambda  (None, 208, 208, 64)         0         ['tf.math.softplus_1[0][0]']
#  )
#
#  tf.math.multiply_1 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_1[0][0]'
#  mbda)                                                              , 'tf.math.tanh_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 208, 208, 64)         4096      ['tf.math.multiply_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 208, 208, 64)         256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  tf.math.softplus_3 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_3[0][0]'
#  mbda)                                                              ]
#
#  tf.math.tanh_3 (TFOpLambda  (None, 208, 208, 64)         0         ['tf.math.softplus_3[0][0]']
#  )
#
#  tf.math.multiply_3 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_3[0][0]'
#  mbda)                                                              , 'tf.math.tanh_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 208, 208, 32)         2048      ['tf.math.multiply_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 208, 208, 32)         128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  tf.math.softplus_4 (TFOpLa  (None, 208, 208, 32)         0         ['batch_normalization_4[0][0]'
#  mbda)                                                              ]
#
#  tf.math.tanh_4 (TFOpLambda  (None, 208, 208, 32)         0         ['tf.math.softplus_4[0][0]']
#  )
#
#  tf.math.multiply_4 (TFOpLa  (None, 208, 208, 32)         0         ['batch_normalization_4[0][0]'
#  mbda)                                                              , 'tf.math.tanh_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 208, 208, 64)         18432     ['tf.math.multiply_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 208, 208, 64)         256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  tf.math.softplus_5 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_5[0][0]'
#  mbda)                                                              ]
#
#  tf.math.tanh_5 (TFOpLambda  (None, 208, 208, 64)         0         ['tf.math.softplus_5[0][0]']
#  )
#
#  tf.math.multiply_5 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_5[0][0]'
#  mbda)                                                              , 'tf.math.tanh_5[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 208, 208, 64)         0         ['tf.math.multiply_3[0][0]',
#  Lambda)                                                             'tf.math.multiply_5[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 208, 208, 64)         4096      ['tf.__operators__.add[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 208, 208, 64)         4096      ['tf.math.multiply_1[0][0]']
#
#  batch_normalization_6 (Bat  (None, 208, 208, 64)         256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_2 (Bat  (None, 208, 208, 64)         256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  tf.math.softplus_6 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_6[0][0]'
#  mbda)                                                              ]
#
#  tf.math.softplus_2 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_2[0][0]'
#  mbda)                                                              ]
#
#  tf.math.tanh_6 (TFOpLambda  (None, 208, 208, 64)         0         ['tf.math.softplus_6[0][0]']
#  )
#
#  tf.math.tanh_2 (TFOpLambda  (None, 208, 208, 64)         0         ['tf.math.softplus_2[0][0]']
#  )
#
#  tf.math.multiply_6 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_6[0][0]'
#  mbda)                                                              , 'tf.math.tanh_6[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_2[0][0]'
#  mbda)                                                              , 'tf.math.tanh_2[0][0]']
#
#  tf.concat (TFOpLambda)      (None, 208, 208, 128)        0         ['tf.math.multiply_6[0][0]',
#                                                                      'tf.math.multiply_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 208, 208, 64)         8192      ['tf.concat[0][0]']
#
#  batch_normalization_7 (Bat  (None, 208, 208, 64)         256       ['conv2d_7[0][0]']
#  chNormalization)
#
#  tf.math.softplus_7 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_7[0][0]'
#  mbda)                                                              ]
#
#  tf.math.tanh_7 (TFOpLambda  (None, 208, 208, 64)         0         ['tf.math.softplus_7[0][0]']
#  )
#
#  tf.math.multiply_7 (TFOpLa  (None, 208, 208, 64)         0         ['batch_normalization_7[0][0]'
#  mbda)                                                              , 'tf.math.tanh_7[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 209, 209, 64)         0         ['tf.math.multiply_7[0][0]']
#  ing2D)
#
#  conv2d_8 (Conv2D)           (None, 104, 104, 128)        73728     ['zero_padding2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 104, 104, 128)        512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  tf.math.softplus_8 (TFOpLa  (None, 104, 104, 128)        0         ['batch_normalization_8[0][0]'
#  mbda)                                                              ]
#
#  tf.math.tanh_8 (TFOpLambda  (None, 104, 104, 128)        0         ['tf.math.softplus_8[0][0]']
#  )
#
#  tf.math.multiply_8 (TFOpLa  (None, 104, 104, 128)        0         ['batch_normalization_8[0][0]'
#  mbda)                                                              , 'tf.math.tanh_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 104, 104, 64)         8192      ['tf.math.multiply_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 104, 104, 64)         256       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_10 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_10[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_10 (TFOpLambd  (None, 104, 104, 64)         0         ['tf.math.softplus_10[0][0]']
#  a)
#
#  tf.math.multiply_10 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_10[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 104, 104, 64)         4096      ['tf.math.multiply_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 104, 104, 64)         256       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_11 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_11[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_11 (TFOpLambd  (None, 104, 104, 64)         0         ['tf.math.softplus_11[0][0]']
#  a)
#
#  tf.math.multiply_11 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_11[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_11[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 104, 104, 64)         36864     ['tf.math.multiply_11[0][0]']
#
#  batch_normalization_12 (Ba  (None, 104, 104, 64)         256       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_12 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_12[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_12 (TFOpLambd  (None, 104, 104, 64)         0         ['tf.math.softplus_12[0][0]']
#  a)
#
#  tf.math.multiply_12 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_12[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_12[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 104, 104, 64)         0         ['tf.math.multiply_10[0][0]',
#  OpLambda)                                                           'tf.math.multiply_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 104, 104, 64)         4096      ['tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  batch_normalization_13 (Ba  (None, 104, 104, 64)         256       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_13 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_13[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_13 (TFOpLambd  (None, 104, 104, 64)         0         ['tf.math.softplus_13[0][0]']
#  a)
#
#  tf.math.multiply_13 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_13[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_13[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 104, 104, 64)         36864     ['tf.math.multiply_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 104, 104, 64)         256       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_14 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_14[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_14 (TFOpLambd  (None, 104, 104, 64)         0         ['tf.math.softplus_14[0][0]']
#  a)
#
#  tf.math.multiply_14 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_14[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_14[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 104, 104, 64)         0         ['tf.__operators__.add_1[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.math.multiply_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 104, 104, 64)         4096      ['tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  conv2d_9 (Conv2D)           (None, 104, 104, 64)         8192      ['tf.math.multiply_8[0][0]']
#
#  batch_normalization_15 (Ba  (None, 104, 104, 64)         256       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_9 (Bat  (None, 104, 104, 64)         256       ['conv2d_9[0][0]']
#  chNormalization)
#
#  tf.math.softplus_15 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_15[0][0]
#  ambda)                                                             ']
#
#  tf.math.softplus_9 (TFOpLa  (None, 104, 104, 64)         0         ['batch_normalization_9[0][0]'
#  mbda)                                                              ]
#
#  tf.math.tanh_15 (TFOpLambd  (None, 104, 104, 64)         0         ['tf.math.softplus_15[0][0]']
#  a)
#
#  tf.math.tanh_9 (TFOpLambda  (None, 104, 104, 64)         0         ['tf.math.softplus_9[0][0]']
#  )
#
#  tf.math.multiply_15 (TFOpL  (None, 104, 104, 64)         0         ['batch_normalization_15[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_15[0][0]']
#
#  tf.math.multiply_9 (TFOpLa  (None, 104, 104, 64)         0         ['batch_normalization_9[0][0]'
#  mbda)                                                              , 'tf.math.tanh_9[0][0]']
#
#  tf.concat_1 (TFOpLambda)    (None, 104, 104, 128)        0         ['tf.math.multiply_15[0][0]',
#                                                                      'tf.math.multiply_9[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 104, 104, 128)        16384     ['tf.concat_1[0][0]']
#
#  batch_normalization_16 (Ba  (None, 104, 104, 128)        512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_16 (TFOpL  (None, 104, 104, 128)        0         ['batch_normalization_16[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_16 (TFOpLambd  (None, 104, 104, 128)        0         ['tf.math.softplus_16[0][0]']
#  a)
#
#  tf.math.multiply_16 (TFOpL  (None, 104, 104, 128)        0         ['batch_normalization_16[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_16[0][0]']
#
#  zero_padding2d_2 (ZeroPadd  (None, 105, 105, 128)        0         ['tf.math.multiply_16[0][0]']
#  ing2D)
#
#  conv2d_17 (Conv2D)          (None, 52, 52, 256)          294912    ['zero_padding2d_2[0][0]']
#
#  batch_normalization_17 (Ba  (None, 52, 52, 256)          1024      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_17 (TFOpL  (None, 52, 52, 256)          0         ['batch_normalization_17[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_17 (TFOpLambd  (None, 52, 52, 256)          0         ['tf.math.softplus_17[0][0]']
#  a)
#
#  tf.math.multiply_17 (TFOpL  (None, 52, 52, 256)          0         ['batch_normalization_17[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_17[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.math.multiply_17[0][0]']
#
#  batch_normalization_19 (Ba  (None, 52, 52, 128)          512       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_19 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_19[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_19 (TFOpLambd  (None, 52, 52, 128)          0         ['tf.math.softplus_19[0][0]']
#  a)
#
#  tf.math.multiply_19 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_19[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_19[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 52, 52, 128)          16384     ['tf.math.multiply_19[0][0]']
#
#  batch_normalization_20 (Ba  (None, 52, 52, 128)          512       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_20 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_20[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_20 (TFOpLambd  (None, 52, 52, 128)          0         ['tf.math.softplus_20[0][0]']
#  a)
#
#  tf.math.multiply_20 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_20[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_20[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 52, 52, 128)          147456    ['tf.math.multiply_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 52, 52, 128)          512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_21 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_21[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_21 (TFOpLambd  (None, 52, 52, 128)          0         ['tf.math.softplus_21[0][0]']
#  a)
#
#  tf.math.multiply_21 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_21[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_21[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 52, 52, 128)          0         ['tf.math.multiply_19[0][0]',
#  OpLambda)                                                           'tf.math.multiply_21[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 52, 52, 128)          16384     ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  batch_normalization_22 (Ba  (None, 52, 52, 128)          512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_22 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_22[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_22 (TFOpLambd  (None, 52, 52, 128)          0         ['tf.math.softplus_22[0][0]']
#  a)
#
#  tf.math.multiply_22 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_22[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_22[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 52, 52, 128)          147456    ['tf.math.multiply_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 52, 52, 128)          512       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_23 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_23[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_23 (TFOpLambd  (None, 52, 52, 128)          0         ['tf.math.softplus_23[0][0]']
#  a)
#
#  tf.math.multiply_23 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_23[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_23[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 52, 52, 128)          0         ['tf.__operators__.add_3[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.math.multiply_23[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 52, 52, 128)          16384     ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  batch_normalization_24 (Ba  (None, 52, 52, 128)          512       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_24 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_24[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_24 (TFOpLambd  (None, 52, 52, 128)          0         ['tf.math.softplus_24[0][0]']
#  a)
#
#  tf.math.multiply_24 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_24[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_24[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 52, 52, 128)          147456    ['tf.math.multiply_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 52, 52, 128)          512       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_25 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_25[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_25 (TFOpLambd  (None, 52, 52, 128)          0         ['tf.math.softplus_25[0][0]']
#  a)
#
#  tf.math.multiply_25 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_25[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_25[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 52, 52, 128)          0         ['tf.__operators__.add_4[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.math.multiply_25[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 52, 52, 128)          16384     ['tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  batch_normalization_26 (Ba  (None, 52, 52, 128)          512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_26 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_26[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_26 (TFOpLambd  (None, 52, 52, 128)          0         ['tf.math.softplus_26[0][0]']
#  a)
#
#  tf.math.multiply_26 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_26[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_26[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 52, 52, 128)          147456    ['tf.math.multiply_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 52, 52, 128)          512       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_27 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_27[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_27 (TFOpLambd  (None, 52, 52, 128)          0         ['tf.math.softplus_27[0][0]']
#  a)
#
#  tf.math.multiply_27 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_27[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_27[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 52, 52, 128)          0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.math.multiply_27[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 52, 52, 128)          16384     ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  batch_normalization_28 (Ba  (None, 52, 52, 128)          512       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_28 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_28[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_28 (TFOpLambd  (None, 52, 52, 128)          0         ['tf.math.softplus_28[0][0]']
#  a)
#
#  tf.math.multiply_28 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_28[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_28[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 52, 52, 128)          147456    ['tf.math.multiply_28[0][0]']
#
#  batch_normalization_29 (Ba  (None, 52, 52, 128)          512       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  tf.math.softplus_29 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_29[0][0]
#  ambda)                                                             ']
#
#  tf.math.tanh_29 (TFOpLambd  (None, 52, 52, 128)          0         ['tf.math.softplus_29[0][0]']
#  a)
#
#  tf.math.multiply_29 (TFOpL  (None, 52, 52, 128)          0         ['batch_normalization_29[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.tanh_29[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 52, 52, 128)          0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.math.multiply_29[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 52, 52, 128)          16384     ['tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  batch_normalization_30 (Ba  (None, 52, 52, 128)          512       ['conv2d_30[0][0]']
#  tchNormalization)
# ...
#
#  conv2d_97 (Conv2D)          (None, 26, 26, 512)          1179648   ['leaky_re_lu_24[0][0]']
#
#  batch_normalization_97 (Ba  (None, 26, 26, 512)          2048      ['conv2d_97[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 26, 26, 256)          131072    ['leaky_re_lu_25[0][0]']
#
#  batch_normalization_98 (Ba  (None, 26, 26, 256)          1024      ['conv2d_98[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 26, 26, 256)          0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  pan_bu2_dn_pad (ZeroPaddin  (None, 27, 27, 256)          0         ['leaky_re_lu_26[0][0]']
#  g2D)
#
#  zero_padding2d_6 (ZeroPadd  (None, 28, 28, 256)          0         ['pan_bu2_dn_pad[0][0]']
#  ing2D)
#
#  conv2d_100 (Conv2D)         (None, 13, 13, 512)          1179648   ['zero_padding2d_6[0][0]']
#
#  batch_normalization_100 (B  (None, 13, 13, 512)          2048      ['conv2d_100[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 13, 13, 512)          0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  tf.concat_9 (TFOpLambda)    (None, 13, 13, 1024)         0         ['leaky_re_lu_28[0][0]',
#                                                                      'leaky_re_lu_5[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 13, 13, 512)          524288    ['tf.concat_9[0][0]']
#
#  batch_normalization_101 (B  (None, 13, 13, 512)          2048      ['conv2d_101[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 13, 13, 512)          0         ['batch_normalization_101[0][0
#                                                                     ]']
#
#  conv2d_102 (Conv2D)         (None, 13, 13, 1024)         4718592   ['leaky_re_lu_29[0][0]']
#
#  batch_normalization_102 (B  (None, 13, 13, 1024)         4096      ['conv2d_102[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 13, 13, 1024)         0         ['batch_normalization_102[0][0
#                                                                     ]']
#
#  conv2d_103 (Conv2D)         (None, 13, 13, 512)          524288    ['leaky_re_lu_30[0][0]']
#
#  batch_normalization_103 (B  (None, 13, 13, 512)          2048      ['conv2d_103[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 13, 13, 512)          0         ['batch_normalization_103[0][0
#                                                                     ]']
#
#  conv2d_104 (Conv2D)         (None, 13, 13, 1024)         4718592   ['leaky_re_lu_31[0][0]']
#
#  batch_normalization_104 (B  (None, 13, 13, 1024)         4096      ['conv2d_104[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 13, 13, 1024)         0         ['batch_normalization_104[0][0
#                                                                     ]']
#
#  conv2d_105 (Conv2D)         (None, 13, 13, 512)          524288    ['leaky_re_lu_32[0][0]']
#
#  batch_normalization_105 (B  (None, 13, 13, 512)          2048      ['conv2d_105[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 13, 13, 512)          0         ['batch_normalization_105[0][0
#                                                                     ]']
#
#  conv2d_106 (Conv2D)         (None, 13, 13, 1024)         4718592   ['leaky_re_lu_33[0][0]']
#
#  conv2d_99 (Conv2D)          (None, 26, 26, 512)          1179648   ['leaky_re_lu_26[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_19[0][0]']
#
#  batch_normalization_106 (B  (None, 13, 13, 1024)         4096      ['conv2d_106[0][0]']
#  atchNormalization)
#
#  batch_normalization_99 (Ba  (None, 26, 26, 512)          2048      ['conv2d_99[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 52, 52, 256)          1024      ['conv2d_92[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 13, 13, 1024)         0         ['batch_normalization_106[0][0
#                                                                     ]']
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  darknet_conv2d_1 (DarknetC  (None, 13, 13, 2)            2050      ['leaky_re_lu_34[0][0]']
#  onv2D)
#
#  darknet_conv2d_5 (DarknetC  (None, 26, 26, 2)            1026      ['leaky_re_lu_27[0][0]']
#  onv2D)
#
#  darknet_conv2d_9 (DarknetC  (None, 52, 52, 2)            514       ['leaky_re_lu_20[0][0]']
#  onv2D)
#
#  darknet_conv2d (DarknetCon  (None, 13, 13, 2)            2050      ['leaky_re_lu_34[0][0]']
#  v2D)
#
#  tf.math.multiply_72 (TFOpL  (None, 13, 13, 2)            0         ['darknet_conv2d_1[0][0]']
#  ambda)
#
#  darknet_conv2d_2 (DarknetC  (None, 13, 13, 1)            1025      ['leaky_re_lu_34[0][0]']
#  onv2D)
#
#  darknet_conv2d_3 (DarknetC  (None, 13, 13, 1)            1025      ['leaky_re_lu_34[0][0]']
#  onv2D)
#
#  darknet_conv2d_4 (DarknetC  (None, 26, 26, 2)            1026      ['leaky_re_lu_27[0][0]']
#  onv2D)
#
#  tf.math.multiply_73 (TFOpL  (None, 26, 26, 2)            0         ['darknet_conv2d_5[0][0]']
#  ambda)
#
#  darknet_conv2d_6 (DarknetC  (None, 26, 26, 1)            513       ['leaky_re_lu_27[0][0]']
#  onv2D)
#
#  darknet_conv2d_7 (DarknetC  (None, 26, 26, 1)            513       ['leaky_re_lu_27[0][0]']
#  onv2D)
#
#  darknet_conv2d_8 (DarknetC  (None, 52, 52, 2)            514       ['leaky_re_lu_20[0][0]']
#  onv2D)
#
#  tf.math.multiply_74 (TFOpL  (None, 52, 52, 2)            0         ['darknet_conv2d_9[0][0]']
#  ambda)
#
#  darknet_conv2d_10 (Darknet  (None, 52, 52, 1)            257       ['leaky_re_lu_20[0][0]']
#  Conv2D)
#
#  darknet_conv2d_11 (Darknet  (None, 52, 52, 1)            257       ['leaky_re_lu_20[0][0]']
#  Conv2D)
#
#  concatenate (Concatenate)   (None, 13, 13, 6)            0         ['darknet_conv2d[0][0]',
#                                                                      'tf.math.multiply_72[0][0]',
#                                                                      'darknet_conv2d_2[0][0]',
#                                                                      'darknet_conv2d_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 26, 26, 6)            0         ['darknet_conv2d_4[0][0]',
#  )                                                                   'tf.math.multiply_73[0][0]',
#                                                                      'darknet_conv2d_6[0][0]',
#                                                                      'darknet_conv2d_7[0][0]']
#
#  concatenate_2 (Concatenate  (None, 52, 52, 6)            0         ['darknet_conv2d_8[0][0]',
#  )                                                                   'tf.math.multiply_74[0][0]',
#                                                                      'darknet_conv2d_10[0][0]',
#                                                                      'darknet_conv2d_11[0][0]']
#
# ==================================================================================================
# Total params: 63982450 (244.07 MB)
# Trainable params: 63916146 (243.82 MB)
# Non-trainable params: 66304 (259.00 KB)
# __________________________________________________________________________________________________

# %%
# from keras.optimizers import Adam
# from keras.callbacks import LearningRateScheduler
# optimizer = Adam(learning_rate=5e-5)

# def scheduler(epoch, lr):
#     if epoch <= 20:
#         return lr
#     elif epoch <= 70:
#         return 3e-5
#     else:
#         return 1e-5

# callback = LearningRateScheduler(scheduler)

# %%
# from utils.tools import get_class_weight

# binary_weight_list = []

# for i in range(len(train_label)):
#     binary_weight_list.append(
#         get_class_weight(
#         train_label[i][..., 4:5],
#         method='binary'
#         )
#     )
# print(binary_weight_list)

# binary_weight_list = [0.1]*3


# ignore_thresh = 0.7
# use_focal_loss = True

# loss_weight = {
#     "xy":1,
#     "wh":1,
#     "conf":5,
#     "prob":1
#     }

# loss_fn = yolo.loss(
#     binary_weight_list,
#     loss_weight=loss_weight,
#     ignore_thresh=ignore_thresh
#     )

# %%
# metrics = yolo.metrics("obj+iou+class")

# %%
# yolo.model.compile(
#     optimizer = optimizer,
#     #optimizer=SGD(learning_rate=1e-10, momentum=0.9, decay=5e-4),
#     loss = loss_fn,
#     metrics = metrics
#     )

# %%
# train_history = yolo.model.fit(
#     train_img,
#     train_label,
#     epochs = n_epoch,
#     batch_size=5,
#     verbose=1,
#     validation_data=(val_img, val_label),
#     callbacks=[callback]
#     )

# %%
yolo.model.load_weights("./yolov4_mish_3_anchor.h5")

# %%
def decode(*label_datas,
           class_num=1,
           threshold=0.5,
           version=1):
    """Decode the prediction from yolo model.

    Args:
        *label_datas: Ndarrays,
            shape: (grid_heights, grid_widths, info).
            Multiple label data can be given at once.
        class_num:  An integer,
            number of classes.
        threshold: A float,
            threshold for quantizing output.
        version: An integer,
            specifying the decode method, yolov1、v2 or v3.

    Return:
        Numpy.ndarray with shape: (N, 7).
            7 values represent:
            x, y, w, h, c, class index, class probability.
    """
    output = []
    for label_data in label_datas:
        grid_shape = label_data.shape[:2]
        if version == 1:
            bbox_num = (label_data.shape[-1] - class_num)//5
            xywhc = np.reshape(label_data[..., :-class_num],
                               (*grid_shape, bbox_num, 5))
            prob = np.expand_dims(
                label_data[..., -class_num:], axis=-2)
        elif version == 2 or version == 3:
            bbox_num = label_data.shape[-1]//(5 + class_num)
            label_data = np.reshape(label_data,
                                    (*grid_shape,
                                     bbox_num, 5 + class_num))
            xywhc = label_data[..., :5]
            prob = label_data[..., -class_num:]
        else:
            raise ValueError("Invalid version: %s" % version)   

        joint_conf = xywhc[..., 4:5]*prob
        where = np.where(joint_conf >= threshold)

        for i in range(len(where[0])):
            x_i = where[1][i]
            y_i = where[0][i]
            box_i = where[2][i]
            class_i = where[3][i]

            x_reg = xywhc[y_i, x_i, box_i, 0]
            y_reg = xywhc[y_i, x_i, box_i, 1]
            w_reg = xywhc[y_i, x_i, box_i, 2]
            h_reg = xywhc[y_i, x_i, box_i, 3]
            conf = xywhc[y_i, x_i, box_i, 4]

            x = (x_i + x_reg)/grid_shape[1]
            y = (y_i + y_reg)/grid_shape[0]
            
            w = w_reg
            h = h_reg
            
            if version == 1:
                p = prob[y_i, x_i, 0, class_i]
            else:
                p = prob[y_i, x_i, box_i, class_i]
            output.append([x, y, w, h, conf, class_i, p])
    output = np.array(output, dtype="float")
    return output

# %%
def cal_iou_nms(xywh_true, xywh_pred):
    """Calculate IOU of two tensors.

    Args:
        xywh_true: A tensor or array-like of shape (..., 4).
            (x, y) should be normalized by image size.
        xywh_pred: A tensor or array-like of shape (..., 4).
    Returns:
        An iou_scores array.
    """
    xy_true = xywh_true[..., 0:2] # N*1*1*1*(S*S)*2
    wh_true = xywh_true[..., 2:4]

    xy_pred = xywh_pred[..., 0:2] # N*S*S*B*1*2
    wh_pred = xywh_pred[..., 2:4]
    
    half_xy_true = wh_true / 2.
    mins_true    = xy_true - half_xy_true
    maxes_true   = xy_true + half_xy_true

    half_xy_pred = wh_pred / 2.
    mins_pred    = xy_pred - half_xy_pred
    maxes_pred   = xy_pred + half_xy_pred       
    
    intersect_mins  = np.maximum(mins_pred,  mins_true)
    intersect_maxes = np.minimum(maxes_pred, maxes_true)
    intersect_wh    = np.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = wh_true[..., 0] * wh_true[..., 1]
    pred_areas = wh_pred[..., 0] * wh_pred[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = intersect_areas/(union_areas + epsilon)
    
    return iou_scores

# %%
# def soft_nms(xywhcp, class_num=1,
#         nms_threshold=0.5, conf_threshold=0.5, sigma=0.5):
#     """Soft Non-Maximum Suppression.

#     Args:
#         xywhcp: output from `decode()`.
#         class_num:  An integer,
#             number of classes.
#         nms_threshold: A float, default is 0.5.
#         conf_threshold: A float,
#             threshold for quantizing output.
#         sigma: A float,
#             sigma for Soft NMS.

#     Returns:
#         xywhcp through nms.
#     """
#     argmax_prob = xywhcp[..., 5].astype("int")

#     xywhcp_new = []
#     for i_class in range(class_num):
#         xywhcp_class = xywhcp[argmax_prob==i_class]
#         xywhc_class = xywhcp_class[..., :5]
#         prob_class = xywhcp_class[..., 6]

#         xywhc_axis0 = np.reshape(
#             xywhc_class, (-1, 1, 5))
#         xywhc_axis1 = np.reshape(
#             xywhc_class, (1, -1, 5))

#         iou_scores = cal_iou_nms(xywhc_axis0, xywhc_axis1)
#         conf = xywhc_class[..., 4]*prob_class
#         sort_index = np.argsort(conf)[::-1]

#         white_list = []
#         delete_list = []
#         for conf_index in sort_index:
#             white_list.append(conf_index)
#             iou_score = iou_scores[conf_index]
#             overlap_indexes = np.where(iou_score >= nms_threshold)[0]

#             for overlap_index in overlap_indexes:
#                 if overlap_index not in white_list:
#                     conf_decay = np.exp(-1*(iou_score[overlap_index]**2)/sigma)
#                     conf[overlap_index] *= conf_decay
#                     if conf[overlap_index] < conf_threshold:
#                         delete_list.append(overlap_index)
#         xywhcp_class = np.delete(xywhcp_class, delete_list, axis=0)
#         xywhcp_new.append(xywhcp_class)
#     xywhcp_new = sorted(xywhcp_new[0], reverse=True, key=lambda x:x[3])
#     xywhcp = np.vstack(xywhcp_new)
#     return xywhcp

# %%
def soft_nms(xywhcp, class_num=1,
        nms_threshold=0.5, conf_threshold=0.5, sigma=0.5):
    """Soft Non-Maximum Suppression.

    Args:
        xywhcp: output from `decode()`.
        class_num:  An integer,
            number of classes.
        nms_threshold: A float, default is 0.5.
        conf_threshold: A float,
            threshold for quantizing output.
        sigma: A float,
            sigma for Soft NMS.

    Returns:
        xywhcp through nms.
    """
    argmax_prob = xywhcp[..., 5].astype("int")

    xywhcp_new = []
    for i_class in range(class_num):
        xywhcp_class = xywhcp[argmax_prob==i_class]
        xywhc_class = xywhcp_class[..., :5]
        prob_class = xywhcp_class[..., 6]

        xywhc_axis0 = np.reshape(
            xywhc_class, (-1, 1, 5))
        xywhc_axis1 = np.reshape(
            xywhc_class, (1, -1, 5))

        iou_scores = cal_iou_nms(xywhc_axis0, xywhc_axis1)
        conf = xywhc_class[..., 4]*prob_class
        sort_index = np.argsort(conf)[::-1]

        white_list = []
        delete_list = []
        for conf_index in sort_index:
            white_list.append(conf_index)
            iou_score = iou_scores[conf_index]
            overlap_indexes = np.where(iou_score >= nms_threshold)[0]

            for overlap_index in overlap_indexes:
                if overlap_index not in white_list:
                    conf_decay = np.exp(-1*(iou_score[overlap_index]**2)/sigma)
                    conf[overlap_index] *= conf_decay
                    if conf[overlap_index] < conf_threshold:
                        delete_list.append(overlap_index)
        
        xywhcp_classes = np.delete(xywhcp_class, delete_list, axis=0)
        xywhcp_new.append(xywhcp_classes)
    xywhcp_new = sorted(xywhcp_new[0], reverse=True, key=lambda x:x[4])
    xywhcp = np.vstack(xywhcp_new)
    return xywhcp

# %%
import cv2
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
image = cv2.imread("D:\\Number Plate Region\\Full_Yolo\\Image_Test\\img_176.jpg")
# image = cv2.imread("D:\Number Plate Region\Full_Yolo\Image_Test\\img_2.jpg")
# image = cv2.imread("D:\\Number Plate Region\\Mydata\\ValImage\\0051_00959_b.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

resized_image = cv2.resize(image, (416, 416), interpolation = cv2.INTER_AREA)
image_pil = resized_image
resized_image = resized_image.astype(float) 
resized_image /= 255

img = np.expand_dims(resized_image, axis=0)
prediction = yolo.model.predict(img)
xywhcp = decode(prediction[2][0],prediction[1][0],prediction[0][0] , class_num=num_classes, threshold=0.5, version=2)

if len(xywhcp) > 0:
    xywhcp = soft_nms(xywhcp, num_classes, 0.5)

print(xywhcp)
idx = len(xywhcp) -1 

img_draw = Image.fromarray(image)
draw = ImageDraw.Draw(img_draw)
for i in range(len(xywhcp)):
    x = int(xywhcp[0][0] * image.shape[1])
    y = int(xywhcp[0][1] * image.shape[0])
    w = int(xywhcp[0][2] * image.shape[1]*1.4)
    h = int(xywhcp[0][3] * image.shape[0]*1.2)
    class_i = int(xywhcp[0][5])

    # Vẽ hình tròn
    radius = 5
    draw.ellipse((x - radius, y - radius, x + radius, y + radius), fill='red')

    # Vẽ hình chữ nhật
    x_min, y_min = int(x - w / 2), int(y - h / 2)
    x_max, y_max = int(x + w / 2), int(y + h / 2)
    draw.rectangle([x_min, y_min, x_max, y_max], outline='red', width=4)

plt.imshow(img_draw)
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[0.67162851 0.4657299  0.15035807 0.20981202 0.7247141  0.
#   0.9998613 ]]

# %% [markdown]
# # Quá trình test

# %%
# image = cv2.imread("D:\\Number Plate Region\\Full_Yolo\\Image_Test\\img_5.jpg")
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# plt.imshow(image)
# plt.show

# %%
# # Resize hình ảnh về kích thước ... chuẩn của mô hình 
# resized_image = cv2.resize(image, (416, 416), interpolation = cv2.INTER_AREA)
# image_pil = resized_image
# resized_image = resized_image.astype(float) 
# resized_image /= 255

# plt.imshow(image_pil)
# plt.show

# %%
# output = []
# version = 2
# class_num = 1
# threshold = 0.5
# for i in range(2, -1, -1):
#     grid_shape = prediction[i][0].shape[:2]
#     if version == 1:
#         bbox_num = (prediction[i][0].shape[-1] - class_num)//5
#         xywhc = np.reshape(prediction[i][0][..., :-class_num],
#                             (*grid_shape, bbox_num, 5))
#         prob = np.expand_dims(
#                 prediction[i][0][..., -class_num:], axis=-2)
#     elif version == 2 or version == 3:
#         bbox_num = prediction[i][0].shape[-1]//(5 + class_num)
#         label_data = np.reshape(prediction[i][0],
#                                 (*grid_shape,
#                                     bbox_num, 5 + class_num))
#         xywhc = label_data[..., :5]
#         prob = label_data[..., -class_num:]
#     else:
#         raise ValueError("Invalid version: %s" % version)   

#     joint_conf = xywhc[..., 4:5]*prob
#     where = np.where(joint_conf >= threshold)
#     # print(where[0])

#     for i in range(len(where[0])):
#         x_i = where[1][i]
#         y_i = where[0][i]
#         box_i = where[2][i]
#         class_i = where[3][i]

#         x_reg = xywhc[y_i, x_i, box_i, 0]
#         y_reg = xywhc[y_i, x_i, box_i, 1]
#         w_reg = xywhc[y_i, x_i, box_i, 2]
#         h_reg = xywhc[y_i, x_i, box_i, 3]
#         conf = xywhc[y_i, x_i, box_i, 4]

#         x = (x_i + x_reg)/grid_shape[1]
#         y = (y_i + y_reg)/grid_shape[0]
        
#         w = w_reg
#         h = h_reg
        
#         if version == 1:
#             p = prob[y_i, x_i, 0, class_i]
#         else:
#             p = prob[y_i, x_i, box_i, class_i]
#         output.append([x, y, w, h, conf, class_i, p])

# xywhcp = np.array(output, dtype="float")

# print(xywhcp)

# %%
# img_draw = Image.fromarray(image)
# draw = ImageDraw.Draw(img_draw)
# for i in range(len(xywhcp)):
#     x = int(xywhcp[i][0] * image.shape[1])
#     y = int(xywhcp[i][1] * image.shape[0])
#     w = int(xywhcp[i][2] * image.shape[1])
#     h = int(xywhcp[i][3] * image.shape[0])
#     class_i = int(xywhcp[0][5])

#     # Vẽ hình tròn
#     radius = 5
#     draw.ellipse((x - radius, y - radius, x + radius, y + radius), fill='red')

#     # Vẽ hình chữ nhật
#     x_min, y_min = int(x - w / 2), int(y - h / 2)
#     x_max, y_max = int(x + w / 2), int(y + h / 2)
#     draw.rectangle([x_min, y_min, x_max, y_max], outline='red', width=4)

# plt.imshow(img_draw)
# plt.show()

# %%
# if len(xywhcp) > 0:
#     xywhcp = soft_nms(xywhcp, num_classes, 0.75)

# print(xywhcp[0])

# %%
# img_draw = Image.fromarray(image)
# draw = ImageDraw.Draw(img_draw)
# for i in range(len(xywhcp)):
#     x = int(xywhcp[0][0] * image.shape[1])
#     y = int(xywhcp[0][1] * image.shape[0])
#     w = int(xywhcp[0][2] * image.shape[1])
#     h = int(xywhcp[0][3] * image.shape[0])
#     class_i = int(xywhcp[0][5])

#     # Vẽ hình tròn
#     radius = 5
#     draw.ellipse((x - radius, y - radius, x + radius, y + radius), fill='red')

#     # Vẽ hình chữ nhật
#     x_min, y_min = int(x - w / 2), int(y - h / 2)
#     x_max, y_max = int(x + w / 2), int(y + h / 2)
#     draw.rectangle([x_min, y_min, x_max, y_max], outline='red', width=4)

# plt.imshow(img_draw)
# plt.show()

# %%
import numpy as np

# Given data
recall = np.array([0.0, 0.38461538461538464, 0.6923076923076923, 0.813953488372093, 0.9, 0.9393939393939394, 0.9493670886075949, 0.9545454545454546, 0.9562841530054644, 0.9574468085106383])
precision = np.array([0.98901099, 0.96153846, 0.92307692, 0.82417582, 0.68131868, 0.3956044, 0.19230769, 0.0989011,  0.02747253, 0.0] )

# Calculate the area under the curve using the trapezoidal rule
area = np.trapz(precision, recall)

print("Area under the precision-recall curve (AUC):", area)
# Out:
# Area under the precision-recall curve (AUC): 0.861114356368644

# %%
import numpy as np

# Given data
recall = np.array([0.0, 0.38461538461538464, 0.6923076923076923, 0.813953488372093, 0.9, 0.9393939393939394, 0.9493670886075949, 0.9545454545454546, 0.9562841530054644, 0.9574468085106383])
precision = np.array([0.0, 0.027472527472527472, 0.0989010989010989, 0.19230769230769232, 0.3956043956043956, 0.6813186813186813, 0.8241758241758241, 0.9230769230769231, 0.9615384615384616, 0.989010989010989])

# Calculate the area under the curve using the trapezoidal rule
AP = np.sum((recall[1:] - recall[:-1]) * precision[1:])

print("Average Precision (AP):", AP)
# Out:
# Average Precision (AP): 0.14109245454336294
